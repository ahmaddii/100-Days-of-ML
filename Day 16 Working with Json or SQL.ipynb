# %% [markdown]
# <h1>Working With JSON Data</h1>

# %%
import pandas as pd

pd.read_json("recipe.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# <h1>Working with SQL Data</h1>

# %%
# !pip install mysql.connecter
# Out:
# ERROR: Could not find a version that satisfies the requirement mysql.connecter (from versions: none)
# ERROR: No matching distribution found for mysql.connecter

# %%
# !pip install mysql.connectore
# Out:
# ERROR: Could not find a version that satisfies the requirement mysql.connectore (from versions: none)
# ERROR: No matching distribution found for mysql.connectore

# %%
# !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 300.5 kB/s  0:01:39291.9 kB/s eta 0:00:02
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp313-cp313-linux_x86_64.whl size=248042 sha256=0b2aa5c6092ce1d037f2af0d7a97e0b6bed4b9254db111b3cfb88433ca099577
#   Stored in directory: /home/malikahmadrasheed/.cache/pip/wheels/4e/c1/23/9423c444a75266a05275c80ebf5c6efe2368388e976b690a0f
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host="localhost",user="root",password="",database="world")

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage WHERE isOfficial LIKE 'T' ",conn)
# Out:
# /tmp/ipykernel_5687/2123587503.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM countrylanguage WHERE isOfficial LIKE 'T' ",conn)

# %%
df
# Out:
#     CountryCode   Language IsOfficial  Percentage
# 0           ABW      Dutch          T         5.3
# 1           AFG       Dari          T        32.1
# 2           AFG     Pashto          T        52.4
# 3           AIA    English          T         0.0
# 4           ALB  Albaniana          T        97.9
# ..          ...        ...        ...         ...
# 233         ZAF  Afrikaans          T        14.3
# 234         ZAF    English          T         8.5
# 235         ZAF      Xhosa          T        17.7
# 236         ZAF       Zulu          T        22.7
# 237         ZWE    English          T         2.2
#
# [238 rows x 4 columns]

# %%
pd.read_sql_query("SELECT * FROM country WHERE Continent = 'Africa' AND GovernmentForm = 'Republic' ",conn)
# Out:
# /tmp/ipykernel_5687/3590534207.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE Continent = 'Africa' AND GovernmentForm = 'Republic' ",conn)
#    Code                                   Name Continent           Region  \
# 0   AGO                                 Angola    Africa   Central Africa
# 1   BDI                                Burundi    Africa   Eastern Africa
# 2   BEN                                  Benin    Africa   Western Africa
# 3   BFA                           Burkina Faso    Africa   Western Africa
# 4   BWA                               Botswana    Africa  Southern Africa
# 5   CAF               Central African Republic    Africa   Central Africa
# 6   CIV                          Côte d’Ivoire    Africa   Western Africa
# ...
