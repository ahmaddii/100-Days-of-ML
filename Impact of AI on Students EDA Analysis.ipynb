# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("ai.csv")

# %%
df.head()
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
df.shape
# Out:
# (50000, 16)

# %%
# first do for the categorical data

sns.countplot(df["Major_Category"])

df["Major_Category"].value_counts()
# Out:
# Major_Category
# STEM          15059
# Business      12538
# Humanities     9994
# Medical        6476
# Arts           5933
# Name: count, dtype: int64

# %%
sns.countplot(df["Prompt_Engineering_Skill"])
# Out:
# <Axes: xlabel='count', ylabel='Prompt_Engineering_Skill'>

# %%
print("Helo")
# Out:
# Helo

# %%
df["Institutional_Policy"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df["Burnout_Risk_Level"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# now come to numerical data

# histogram

import matplotlib.pyplot as plt

plt.hist(df["Pre_Semester_GPA"])
# Out:
# (array([   30.,   218.,   710.,  1997.,  4019.,  6563.,  9256., 11300.,
#         10644.,  5263.]),
#  array([1.183 , 1.4645, 1.746 , 2.0275, 2.309 , 2.5905, 2.872 , 3.1535,
#         3.435 , 3.7165, 3.998 ]),
#  <BarContainer object of 10 artists>)

# %%
# now distplot improvement of the histogram ye hmain probality density function provide krta ha tell us probability

sns.distplot(df["Pre_Semester_GPA"])
# Out:
# /tmp/ipykernel_11172/1347843371.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Pre_Semester_GPA"])
# <Axes: xlabel='Pre_Semester_GPA', ylabel='Density'>

# %%
sns.boxplot(df["Pre_Semester_GPA"])
# Out:
# <Axes: ylabel='Pre_Semester_GPA'>

# %%
df["Pre_Semester_GPA"].min()
# Out:
# 1.183

# %%
df["Pre_Semester_GPA"].max()
# Out:
# 3.998

# %%
df["Pre_Semester_GPA"].skew()
# Out:
# np.float64(-0.602042795770214)
