# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open("pipe.pkl","rb"))

# %%
test_input_2 = np.array([2,"male",31.0,0,0,10.5,"S"],dtype=object).reshape(1,7)

# what is reshape in numpy it converst 1D to 2D that 1 is the passenger means no of samples or 2nd one 7 is the no of 
# features you are passing in our case 7 columns if 8 we pass 8

# %%
pipe.predict(test_input_2)
# Out:
# /home/malikahmadrasheed/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/malikahmadrasheed/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
