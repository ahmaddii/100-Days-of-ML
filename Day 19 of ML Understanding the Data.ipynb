# %% [markdown]
# <h1>Questions after You receive the dataSet</h1>

# %%
import pandas as pd

df = pd.read_csv("train2.csv")

# %% [markdown]
# <h1>1st How Big is Data is </h1>

# %%
# How big is the data

df.shape
# Out:
# (891, 12)

# %% [markdown]
# <h1>How does data look like means its columns and rows</h1>

# %%
# how does the data looks like

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <h1>Better practise you load random rows data</h1>

# %%
# some time we use sample function to remove biasness to get random rows e.g

df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 739          740         0       3     Nankoff, Mr. Minko  male   NaN      0
# 625          626         0       1  Sutton, Mr. Frederick  male  61.0      0
# 321          322         0       3       Danoff, Mr. Yoto  male  27.0      0
# 398          399         0       2       Pain, Dr. Alfred  male  23.0      0
# 563          564         0       3      Simmons, Mr. John  male   NaN      0
#
#      Parch           Ticket     Fare Cabin Embarked
# 739      0           349218   7.8958   NaN        S
# 625      0            36963  32.3208   D50        S
# 321      0           349219   7.8958   NaN        S
# 398      0           244278  10.5000   NaN        S
# 563      0  SOTON/OQ 392082   8.0500   NaN        S

# %% [markdown]
# <h1>Importent check data types of column</h1>

# %%
# what is the data types of the cols

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <h1>Are there any missing values in the data</h1>

# %%
# Are there any missing values in your data
# how to find exact number of missing values

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# <h1>Check data how does it look mathematically</h1>

# %%
# how does data look mathematically

df.describe() # har numeric column per
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <h1>Removing duplicates</h1>

# %%
# are there any duplicate values

df.duplicated().sum() # df.drop_duplicates() which remove the duplictes rows in the data
# Out:
# np.int64(0)

# %% [markdown]
# <h1>Co relation between numeric data</h1>

# %%
# how is the corelation between cols

df.corr(numeric_only=True) # why pass numeric only in the argument of corr because corelation we only find for the numeric values in which ouptut depend on the inpit
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.corr(numeric_only=True)["Survived"]
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
