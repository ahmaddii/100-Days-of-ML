# %%
import numpy as np
import pickle

# %%
pipe = pickle.load(open("emp_pred.pkl","rb"))

# %%
test_input = np.array([   
    
    35,                 # age
    "Private",          # workclass
    "Bachelors",        # education
    "Married-civ-spouse", # marital.status
    "Exec-managerial",  # occupation
    "Male",             # sex
    45    ],dtype=object).reshape(1,7) # why one 1,7 1 is the no of sample mean one person or 7 input features and scikit learn accept 2d array

# %%
pipe.predict(test_input)
# Out:
# /home/malikahmadrasheed/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/malikahmadrasheed/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array(['<=50K'], dtype=object)

# %%
test_input2 = np.array([
    [35, "Private", "Bachelors", "Married-civ-spouse", "Exec-managerial", "Male", 45],
    [22, "Private", "HS-grad", "Never-married", "Sales", "Female", 25],
    [50, "Self-emp-not-inc", "Masters", "Married-civ-spouse", "Prof-specialty", "Male", 60]
], dtype=object).reshape(3,7)

# %%
pipe.predict(test_input2)
# Out:
# /home/malikahmadrasheed/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /home/malikahmadrasheed/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array(['<=50K', '<=50K', '>50K'], dtype=object)
